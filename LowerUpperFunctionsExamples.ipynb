# %%
import numpy as np
import matplotlib.pyplot as plt
import LowerUpperFunctions as luf

# %%
from importlib import reload
import LowerUpperFunctions as luf
reload(luf)


# Define the function f(x) with noise
def f(x, noise_level=0.1):
#    noise = np.random.normal(0, noise_level, size=x.shape)  # Add Gaussian noise
#    return x ** 2 + 1+noise
    return np.maximum(x ** 2-1,0)+1 
#    return np.maximum(x ** 2-1,0) 

# Number of triangular fuzzy sets
a=-2
n = 3  # Change this value as needed
k = 1 # The distance between parameters

# Number of triangular fuzzy sets
#a=-3
#n = 11  # Change this value as needed
#k = 0.5 # The distance between parameters

# Precompute the parameters for triangular fuzzy sets
params = [( a+ (i - 1) * k, a + i * k, a + (i + 1) * k) for i in range(1, n + 1)]

# Define the domain of x for plotting
x_values = np.linspace(-2.5, 2.5, 500)
f_values = f(x_values)

# Compute components F_A_up
F_A_up = luf.F_A_upT(params, x_values, f_values)

# Compute upper function f_{\mathcal{A}}^\uparrow
f_A_up_values = np.array([luf.f_A_upT(x,F_A_up,params) for x in x_values])
print(F_A_up)
# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_up_values, label='$f_{\\mathcal{A}}^{\\uparrow}(x)$', color='green', linewidth=2)
plt.plot(x_values, f_values, label='$f(x) = x^2+1$', color='purple', linewidth=2,ls='--')
#plt.title('Generalized Inverse Upward Transformation with Multiple Fuzzy Sets')
plt.xlabel('$x$', fontsize=16)
plt.ylabel('$f_{\\mathcal{A}}^{\\uparrow}(x)$ and $f(x)$', fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.legend(fontsize=16)
plt.grid(True)
plt.xlim(-2.5, 2.5)
plt.ylim(-0.5, 10)
plt.tight_layout()

plt.savefig("UFZero2.pdf",format='pdf')

plt.show()

# Plotting all fuzzy sets
luf.plot_triangular_fuzzy_sets(params)
# Out:
# [np.float64(1.185147397094984), np.float64(0.9949899799599198), np.float64(1.185147397094984)]
# d:\Documents\Python\LowerUpperFunctions\LowerUpperFunctions.py:166: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.xlim(-2.5, 2.5)

# %%
from importlib import reload
import LowerUpperFunctions as luf
reload(luf)
# Define the function f(x) with noise
def f(x, noise_level=0.1):
    noise = np.random.normal(0, noise_level, size=x.shape)  # Add Gaussian noise
    return x ** 2 + 1+noise
#    return np.maximum(x ** 2-1,0)+1 
#    return np.maximum(x ** 2-1,0) 

# Number of triangular fuzzy sets
a=-3
n = 11  # Change this value as needed
k = 0.5 # The distance between parameters

# Precompute the parameters for triangular fuzzy sets
params = [( a + (i - 1) * k, a + i * k, a + (i + 1) * k) for i in range(1, n + 1)]

# Define the domain of x for plotting
x_values = np.linspace(-2.5, 2.5, 500)
f_values = f(x_values)  # Pre-compute f(x) over the domain

# Compute components F_A_up
F_A_up = luf.F_A_upT(params, x_values, f_values)

# Compute upper function f_{\mathcal{A}}^\uparrow
f_A_up_values = np.array([luf.f_A_upT(x,F_A_up,params) for x in x_values])
print(F_A_up)
# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_up_values, label='$f_{\\mathcal{A}}^{\\uparrow}(x)$', color='green', linewidth=2)
plt.plot(x_values, f_values, label='$f(x)$', color='purple', linewidth=2,ls='--')
#plt.title('Generalized Inverse Upward Transformation with Multiple Fuzzy Sets')
plt.xlabel('$x$',fontsize=16)
plt.ylabel('$f_{\\mathcal{A}}^{\\uparrow}(x)$ and $f(x)$',fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.legend(fontsize=16)
plt.grid(True)
plt.xlim(-2.5, 2.5)
#plt.ylim(-0.5, 10)
plt.tight_layout()

plt.savefig("UFZero2.pdf",format='pdf')

plt.show()

# Compute components F_A_down
F_A_down = luf.F_A_downT(params,x_values, f_values)


# Compute lower function f_{\mathcal{A}}^\downarrow
f_A_down_values = np.array([luf.f_A_downT(x,F_A_down,params) for x in x_values])

# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_down_values, label='$f_{\\mathcal{A}}^{\\downarrow}(x)$', color='red', linewidth=2)
plt.plot(x_values, f_values, label='$f(x)$', color='purple', linewidth=2, ls='--')
#plt.title('Generalized Inverse Downward Transformation with Multiple Fuzzy Sets')
plt.xlabel('$x$',fontsize=16)
plt.ylabel('$f_{\\mathcal{A}}^{\\downarrow}(x)$ and $f(x)$',fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend(fontsize=16)
plt.xlim(-2.5, 2.5)
#plt.ylim(-0.5, 5)
plt.tight_layout()

plt.savefig("LowerTrian.pdf",format='pdf')
plt.show()

# Plotting all fuzzy sets
luf.plot_triangular_fuzzy_sets(params)
# Out:
# [np.float64(7.426820581652944), np.float64(5.006268760311227), np.float64(3.382449072232406), np.float64(2.0743946662379833), np.float64(1.3420894702169217), np.float64(1.1705499766726577), np.float64(1.4016029154613905), np.float64(2.0404813494197303), np.float64(3.264741354779887), np.float64(4.995699750703385), np.float64(7.262040399283056)]

# %% [markdown]
# # Plot triangular fuzzy sets

# %%
reload(luf)
a=-3 # Starting point
n = 11 # Number of triangular fuzzy sets
k = 0.5  # The distance between parameters

# Precompute the parameters for triangular fuzzy sets
params = [(a + (i - 1) * k, a + i * k, a + (i + 1) * k) for i in range(1, n + 1)]


# Plotting all fuzzy sets
luf.plot_triangular_fuzzy_sets(params)

# %% [markdown]
# # Ploting Gaussian fuzzy sets

# %%
reload(luf)
import numpy as np
import matplotlib.pyplot as plt

# Number of Gaussian fuzzy sets
n = 7 #14 #7  # Change this value as needed
sigma = 0.5  # Standard deviation for Gaussian sets

# Precompute the centers for Gaussian fuzzy sets
centers = np.linspace(-3, 3, n)  # Centers evenly spaced between -2 and 2


# Plotting all Gaussian fuzzy sets
luf.plot_gaussian_fuzzy_sets(centers, sigma)
# Save plot as PDF

# %% [markdown]
# ## L and U functions with Gaussian FSets

# %%
# Define the function f(x)
def f(x, noise_level=0.3):
    noise = np.random.normal(0, noise_level, size=x.shape)  # Add Gaussian noise
    return np.sin(2*x) + 2+noise

# Define the range of x values
x_values = np.linspace(-2.5, 2.5, 500)
f_x_values = f(x_values)  # Precompute f(x) values

# %%
from importlib import reload
import LowerUpperFunctions as luf
reload(luf)

# Number of Gaussian fuzzy sets
n = 14 #7 #14  # Change this value as needed
sigma = 0.5  # Standard deviation for Gaussian sets

# Precompute the centers for Gaussian fuzzy sets
centers = np.linspace(-3, 3, n)  # Centers evenly spaced between -2 and 2

F_A_down=luf.F_A_downG(centers, sigma, x_values,f_x_values)

# Compute f_{\mathcal{A}}^\downarrow
f_A_down_values = np.array([luf.f_A_downG(x,F_A_down,sigma,centers) for x in x_values])

# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_down_values, label='$f_{\\mathcal{A}}^{\\downarrow}(x)$', color='red', linewidth=2)
plt.plot(x_values, f_x_values, label='$f(x)$', color='purple', linewidth=2)
#plt.title('Inverse Downward Transformation with Gaussian Fuzzy Sets')
plt.xlabel('$x$',fontsize=16)
plt.ylabel('$y$',fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend(fontsize=16)
plt.xlim(-2.5, 2.5)
plt.ylim(0, 6)
plt.tight_layout()

plt.savefig("DF.pdf",format='pdf')

plt.show()


# Compute components
F_A_up=luf.F_A_upG(centers, sigma, x_values,f_x_values)

# Compute f_{\mathcal{A}}^\uparrow
f_A_up_values = np.array([luf.f_A_upG(x,F_A_up,sigma,centers) for x in x_values])

# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_up_values, label='$f_{\\mathcal{A}}^{\\uparrow}(x)$', color='green', linewidth=2)
plt.plot(x_values, f_x_values, label='$f(x) $', color='purple', linewidth=2)
#plt.title('Inverse Upward Transformation with Gaussian Fuzzy Sets')
plt.xlabel('$x$',fontsize=16)
plt.ylabel('$y$',fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend(fontsize=16)
plt.xlim(-2.5, 2.5)
plt.ylim(0,6 )
plt.tight_layout()
plt.savefig("UF.pdf",format='pdf')

plt.show()

# %% [markdown]
# Bell shaped MF

# %%
reload(luf)
# Number of bell functions
n = 10  # Change this value as needed
a = 1.5  # Parameter for the bell function width
b = 2.0  # Parameter for the bell function shape

# Precompute the centers for bell functions
centers = np.linspace(-3, 3, n)  # Centers evenly spaced between -2 and 2

# Define the range of x values
x_values = np.linspace(-2.5, 2.5, 500)

# Plotting all Bell fuzzy sets
luf.plot_bell_fuzzy_sets(x_values,centers, a,b)

# %% [markdown]
# L and U functions for bell shape MF

# %%
# Define the function f(x)
def f(x):
    return np.sin(2*x) +2

# Define the range of x values
x_values = np.linspace(-2.5, 2.5, 500)
f_x_values = f(x_values)  # Precompute f(x) values

# %%
from importlib import reload
import LowerUpperFunctions as luf
reload(luf)



# Number of bell functions
n = 10  # Change this value as needed
a = 0.8  # Parameter for the bell function width
b = 2.0  # Parameter for the bell function shape

# Precompute the centers for bell functions
centers = np.linspace(-3, 3, n)  # Centers evenly spaced between -2 and 2

# Compute components
F_A_down=luf.F_A_downB(centers,a,b,x_values,f_x_values)
# Compute f_{\mathcal{A}}^\downarrow
f_A_down_values = np.array([luf.f_A_downB(x,F_A_down,centers,a,b) for x in x_values])

# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_down_values, label='$f_{\\mathcal{A}}^{\\downarrow}(x)$', color='red', linewidth=2)
plt.plot(x_values, f_x_values, label='$f(x)$', color='purple', linewidth=2, ls='--')
#plt.title('Inverse Downward Transformation with Generalized Bell Functions')
plt.xlabel('$x$',fontsize=16)
plt.ylabel('$y$',fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend(fontsize=16)
plt.xlim(-2.5, 2.5)
plt.ylim(0, 4)
plt.tight_layout()
plt.savefig("DF.pdf",format='pdf')

plt.show()

# Compute components 
F_A_up=luf.F_A_upB(centers,a,b,x_values,f_x_values)
# Compute f_{\mathcal{A}}^\uparrow
f_A_up_values = np.array([luf.f_A_upB(x,F_A_up,centers,a,b) for x in x_values])

# Plotting the result
plt.figure(figsize=(10, 6))
plt.plot(x_values, f_A_up_values, label='$f_{\\mathcal{A}}^{\\uparrow}(x)$', color='green', linewidth=2)
plt.plot(x_values, f_x_values, label='$f(x)$', color='purple', linewidth=2)
#plt.title('Inverse Upward Transformation with Generalized Bell Functions')
plt.xlabel('$x$',fontsize=16)
plt.ylabel('$y$',fontsize=16)
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend(fontsize=16)
plt.xlim(-2.5, 2.5)
plt.ylim(0, 4)
plt.tight_layout()
plt.savefig("UF.pdf",format='pdf')

plt.show()
