# %%
import numpy as np
import matplotlib.pyplot as plt
import LowerUpperFunctionsDatasets as luf

# %%
# příklad: 2 nezávislé proměnné X1, X2
n1 = 3
a1 = -2
k1 = 1
params_X1 = [(a1 + (i-1)*k1, a1 + i*k1, a1 + (i+1)*k1) for i in range(1, n1+1)]

n2 = 2
a2 = 0
k2 = 2
params_X2 = [(a2 + (i-1)*k2, a2 + i*k2, a2 + (i+1)*k2) for i in range(1, n2+1)]

feature_partitions = {
    "X1": params_X1,
    "X2": params_X2,
    # případně další X3, X4, ...
}
f_values = df["Y"].values
results = luf.compute_F_A_up_for_all_combinations(df, feature_partitions, f_values)

x = {"X1": 0.5, "X2": 3.2}
f_hat = luf.f_A_upT_multi(x, feature_partitions, results)
